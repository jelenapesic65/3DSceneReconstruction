# %% [markdown]
# ## Notes
#
# -Dont forget to change the directory file to "\data\streeview\mask' ! /content/3DGS/data/streeview/mask/
#
# -Dont forget to put the data folder ine 3DGS folder \
# -The inclusion for knn!!!!
#
# -remove antialiasing
#
# -line 71,135 remove last return param in __init__ gaussian rendering
#
# -try to change, possible double masking, line 325:
# opacity_mask = render_pkg['render_opacity'] > 0.5
# opacity_mask = opacity_mask.unsqueeze(0).repeat(3, 1, 1)
# -delete the multiplication
# save_image(image * opacity_mask, iteration, './saved_images')

# %%
# !git clone https://github.com/ThinkXca/3DGS.git --recursive
# %cd /content
# Out:
# Cloning into '3DGS'...
# remote: Enumerating objects: 1715, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 1715 (delta 32), reused 0 (delta 0), pack-reused 1664 (from 2)
# Receiving objects: 100% (1715/1715), 91.62 MiB | 16.08 MiB/s, done.
# Resolving deltas: 100% (929/929), done.
# Updating files: 100% (1638/1638), done.
# /content

# %%
'''!pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cu118

# Install other dependencies
# !pip install plyfile==0.8.1 tqdm

# Navigate to the 3DGS directory
# %cd /content/3DGS

# Install diff-gaussian-rasterization (this worked)
# %cd submodules/diff-gaussian-rasterization
# !pip install .
# %cd /content/3DGS

# For simple-knn, we need to modify the setup.py for compatibility
# %cd submodules/simple-knn

# Let's check what's in the setup.py and potentially fix it
# !cat setup.py

# Common fix for simple-knn - modify the compilation flags
# !sed -i 's/"-std=c++14"/"-std=c++17", "-D_GLIBCXX_USE_CXX11_ABI=1"/g' setup.py

# Try building again
# !pip install .
# %cd /content/3DGS

# For Propagation_SSIM, check if it has setup requirements
# %cd submodules/Propagation_SSIM
# !pip install .
# %cd /content/3DGS

# Verify installation
# !python -c "import torch; print('PyTorch:', torch.__version__); print('CUDA:', torch.cuda.is_available())"
# !python -c "import diff_gaussian_rasterization; print('Diff Gaussian Rasterization imported successfully')""'''

# %%
# !nvcc --version
# !nvidia-smi

# Set the CUDA architecture to match Colab's GPU (usually sm_80 for A100/T4)
import os
os.environ["CUDA_HOME"] = "/usr/local/cuda"
os.environ["TORCH_CUDA_ARCH_LIST"] = "7.5;8.0;8.6"  # Common architectures for Colab GPUs

# Install with specific build flags
# %cd /content/3DGS/submodules/diff-gaussian-rasterization
# !python setup.py install
# %cd /content/3DGS
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# Thu Sep 25 09:02:43 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# ...

# %%
# !sed -i '1i#include <cfloat>' /content/3DGS/submodules/simple-knn/simple_knn.cu

# %cd submodules/simple-knn
# !pip install .  --verbose
# %cd /content/3DGS
# Out:
# /content/3DGS/submodules/simple-knn
# Using pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Processing /content/3DGS/submodules/simple-knn
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-1k35rrfe/simple_knn.egg-info
#   writing /tmp/pip-pip-egg-info-1k35rrfe/simple_knn.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-1k35rrfe/simple_knn.egg-info/dependency_links.txt
#   writing top-level names to /tmp/pip-pip-egg-info-1k35rrfe/simple_knn.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-1k35rrfe/simple_knn.egg-info/SOURCES.txt'
# ...

# %%
# !pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install plyfile==0.8.1 tqdm
# %cd content
#!pip install 3DGS/submodules/diff-gaussian-rasterization
#!pip install 3DGS/submodules/simple-knn
#!pip install 3DGS/submodules/Propagation_SSIM
# %cd submodules/diff-gaussian-rasterization
# !pip install .
# %cd /content/3DGS

# Install simple-knn
#!sed -i '1i#include <cfloat>' /content/3DGS/submodules/simple-knn/simple_knn.cu

#%cd submodules/simple-knn
#!pip install .
#%cd /content/3DGS

# Install Propagation_SSIM (if it has a setup.py)
# %cd submodules/Propagation_SSIM
# !pip install .
# %cd /content/3DGS

# !nvcc --version

# !python -c "import torch; print(f'PyTorch version: {torch.__version__}'); print(f'CUDA available: {torch.cuda.is_available()}')"
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ERROR: Could not find a version that satisfies the requirement torch==1.12.1+cu113 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0)
# ERROR: No matching distribution found for torch==1.12.1+cu113
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
# !unzip -q /content/streeview.zip -d /content/3DGS/data/
# !pip install open3d
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 116.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 18.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 94.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 79.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...

# %%
#!pip install 3DGS/submodules/Propagation_SSIM

# Don't forget to modify the mask location before running the code. cameras.py 54
# %cd /content/3DGS

# !python train.py -s data/streeview --eval

#!python train.py -s data/peoplecarstreeview --eval
# Out:
# /content/3DGS
# 2025-09-25 09:14:58.400011: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-25 09:14:58.418648: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758791698.440368    6520 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758791698.446990    6520 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 150.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 95.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 84.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...

# %%
# 1. Navigate to your output directory
# %cd /content/3DGS
# !zip -r trained_model.zip ./output/ ./saved_images/ ./saved_gt_images/

# 2. Download the compressed file
from google.colab import files
files.download('trained_model.zip')


# 3. Compress and download the ENTIRE output folder (recommended)
#!zip -r full_output.zip output/

# 4. Download the compressed file
#from google.colab import files
#files.download('full_output.zip')
# Out:
# /content/3DGS
#   adding: output/ (stored 0%)
#   adding: output/66179832-1/ (stored 0%)
#   adding: output/66179832-1/events.out.tfevents.1758791643.9ba8a676a76b.6231.0 (deflated 9%)
#   adding: output/66179832-1/cfg_args (deflated 26%)
#   adding: output/66179832-1/input.ply (deflated 44%)
#   adding: output/66179832-1/cameras.json (deflated 64%)
#   adding: output/9dc078dd-d/ (stored 0%)
#   adding: output/9dc078dd-d/point_cloud/ (stored 0%)
#   adding: output/9dc078dd-d/point_cloud/iteration_20000/ (stored 0%)
#   adding: output/9dc078dd-d/point_cloud/iteration_20000/point_cloud.ply (deflated 26%)
#   adding: output/9dc078dd-d/point_cloud/iteration_1/ (stored 0%)
#   adding: output/9dc078dd-d/point_cloud/iteration_1/point_cloud.ply (deflated 88%)
#   adding: output/9dc078dd-d/point_cloud/iteration_30000/ (stored 0%)
#   adding: output/9dc078dd-d/point_cloud/iteration_30000/point_cloud.ply (deflated 26%)
#   adding: output/9dc078dd-d/point_cloud/iteration_7000/ (stored 0%)
# ...
